# %%
# This code uses https://www.kaggle.com/code/electrichands/spotify-similarity-based/notebook, licensed under Apache License 2.0.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Data Loading

# %%
import pandas

df = pd.read_csv('/content/updated_dataset_with_youtube_urls.csv', index_col=0)

# %%
df.head()
# Out:
#                       track_id                  artists  \
# SongID
# 0       3nqQXoyQOWXiESFLlDF1hG     Sam Smith;Kim Petras
# 1       2tTmW7RDtMQtBk7m2rYeSw         Bizarrap;Quevedo
# 2       4uUG5RXrOk84mYEfFvj3cK  David Guetta;Bebe Rexha
# 3       5ww2BF9slyYgNOk37BlC4u            Manuel Turizo
# 4       1IHWl5LamUGEuP4ozKQSXZ                Bad Bunny
#
#                                    album_name  \
# SongID
# 0                   Unholy (feat. Kim Petras)
# 1       Quevedo: Bzrp Music Sessions, Vol. 52
# 2                             I'm Good (Blue)
# 3                                  La Bachata
# 4                            Un Verano Sin Ti
#
#                                    track_name  popularity  duration_ms  \
# SongID
# 0                   Unholy (feat. Kim Petras)         100       156943
# 1       Quevedo: Bzrp Music Sessions, Vol. 52          99       198937
# 2                             I'm Good (Blue)          98       175238
# 3                                  La Bachata          98       162637
# 4                            Tití Me Preguntó          97       243716
#
#         explicit  danceability  energy  key  ...  mode  speechiness  \
# SongID                                       ...
# 0          False         0.714   0.472    2  ...     1       0.0864
# 1          False         0.621   0.782    2  ...     1       0.0440
# 2           True         0.561   0.965    7  ...     0       0.0343
# 3          False         0.835   0.679    7  ...     0       0.0364
# 4          False         0.650   0.715    5  ...     0       0.2530
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# SongID
# 0            0.01300          0.000005     0.266    0.238  131.121
# 1            0.01250          0.033000     0.230    0.550  128.033
# 2            0.00383          0.000007     0.371    0.304  128.040
# 3            0.58300          0.000002     0.218    0.850  124.980
# 4            0.09930          0.000291     0.126    0.187  106.672
#
#         time_signature  track_genre  \
# SongID
# 0                    4        dance
# 1                    4      hip-hop
# 2                    4          pop
# 3                    4    reggaeton
# 4                    4       reggae
#
#                                               YouTube URL
# SongID
# 0       https://www.youtube.com/watch?v=Uq9gPaIzbe8&pp...
# 1       https://www.youtube.com/watch?v=A_g3lMcWVy0&pp...
# 2       https://www.youtube.com/watch?v=90RLzVUuXe4&pp...
# 3       https://www.youtube.com/watch?v=TiM_TFpT_DE&pp...
# 4       https://www.youtube.com/watch?v=Cr8K88UcO0s&pp...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81344 entries, 0 to 81343
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          81344 non-null  object
#  1   artists           81343 non-null  object
#  2   album_name        81343 non-null  object
#  3   track_name        81343 non-null  object
#  4   popularity        81344 non-null  int64
#  5   duration_ms       81344 non-null  int64
#  6   explicit          81344 non-null  bool
#  7   danceability      81344 non-null  float64
#  8   energy            81344 non-null  float64
#  9   key               81344 non-null  int64
#  10  loudness          81344 non-null  float64
#  11  mode              81344 non-null  int64
#  12  speechiness       81344 non-null  float64
#  13  acousticness      81344 non-null  float64
#  14  instrumentalness  81344 non-null  float64
#  15  liveness          81344 non-null  float64
#  16  valence           81344 non-null  float64
#  17  tempo             81344 non-null  float64
#  18  time_signature    81344 non-null  int64
#  19  track_genre       81344 non-null  object
#  20  YouTube URL       3379 non-null   object
# dtypes: bool(1), float64(9), int64(5), object(6)
# memory usage: 13.1+ MB

# %% [markdown]
# ### Check Missing Values

# %%
df.isnull().sum()
# Out:
# track_id                0
# artists                 1
# album_name              1
# track_name              1
# popularity              0
# duration_ms             0
# explicit                0
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# time_signature          0
# track_genre             0
# YouTube URL         77965
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# YouTube URL         0
# dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame and 'track_id' is the column containing track IDs
num_duplicates = df.duplicated('track_id').sum()
print("Number of duplicate track IDs:", num_duplicates)

# Drop rows with duplicate track IDs
df.drop_duplicates('track_id', inplace=True)

# Confirm that duplicates have been dropped
print("Number of unique track IDs after dropping duplicates:", len(df))
# Out:
# Number of duplicate track IDs: 0
# Number of unique track IDs after dropping duplicates: 3379

# %%
df.shape
# Out:
# (3379, 21)

# %%
df.describe()
# Out:
#         popularity    duration_ms  danceability       energy          key  \
# count  3379.000000    3379.000000   3379.000000  3379.000000  3379.000000
# mean     74.854987  217736.483575      0.617018     0.663686     5.335010
# std       5.111572   56469.766303      0.154325     0.197523     3.578055
# min      69.000000   53247.000000      0.000000     0.001890     0.000000
# 25%      71.000000  182333.000000      0.517500     0.537000     2.000000
# 50%      74.000000  210772.000000      0.629000     0.692000     5.000000
# 75%      78.000000  244435.000000      0.732000     0.817500     8.000000
# max     100.000000  595105.000000      0.980000     0.996000    11.000000
#
#           loudness         mode  speechiness  acousticness  instrumentalness  \
# count  3379.000000  3379.000000  3379.000000   3379.000000       3379.000000
# mean     -6.824595     0.612607     0.080319      0.233086          0.037571
# std       3.568718     0.487227     0.079997      0.265451          0.148064
# min     -38.523000     0.000000     0.000000      0.000005          0.000000
# 25%      -8.239000     0.000000     0.035000      0.021450          0.000000
# 50%      -6.065000     1.000000     0.048800      0.119000          0.000005
# 75%      -4.595500     1.000000     0.085400      0.367500          0.000630
# max      -0.140000     1.000000     0.724000      0.996000          1.000000
#
#           liveness      valence        tempo  time_signature
# count  3379.000000  3379.000000  3379.000000     3379.000000
# mean      0.174910     0.509776   120.916596        3.941107
# std       0.132583     0.231438    28.081582        0.308398
# min       0.021000     0.000000     0.000000        0.000000
# 25%       0.092500     0.330000    99.959000        4.000000
# 50%       0.123000     0.506000   119.990000        4.000000
# 75%       0.219000     0.691000   137.981500        4.000000
# max       0.950000     0.979000   208.951000        5.000000

# %%
from scipy import stats

# Define a function to find outliers using Z-score
def find_outliers(dataframe, column_name):
    # Calculate Z-scores
    z_scores = stats.zscore(dataframe[column_name])
    # Define a threshold for identifying outliers
    threshold = 3
    # Get boolean array of outliers
    outliers = (z_scores > threshold) | (z_scores < -threshold)
    # Return the dataframe of outliers
    return dataframe[outliers]

# Find outliers for each numerical column in the dataset
numerical_columns = ['popularity', 'duration_ms', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
outliers_dict = {}

for column in numerical_columns:
    outliers_dict[column] = find_outliers(df, column)

# Print the number of outliers for each column
for column, outliers_df in outliers_dict.items():
    print(f"{column} has {len(outliers_df)} outliers.")
# Out:
# popularity has 27 outliers.
# duration_ms has 45 outliers.
# danceability has 11 outliers.
# energy has 24 outliers.
# loudness has 38 outliers.
# speechiness has 87 outliers.
# acousticness has 0 outliers.
# instrumentalness has 112 outliers.
# liveness has 88 outliers.
# valence has 0 outliers.
# tempo has 7 outliers.

# %%
new_df = df.copy()

# %%
import matplotlib.pyplot as plt

# Convert duration_ms to minutes
df['duration_min'] = df['duration_ms'] / 60000

# Plot the distribution of duration_min
plt.figure(figsize=(10, 6))
plt.hist(df['duration_min'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('Duration (min)')
plt.ylabel('Frequency')
plt.title('Distribution of Duration (min)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import numpy as np

# Define the bin edges for the intervals
bin_edges = np.arange(0, df['duration_min'].max() + 5, 5)

# Use cut to create bins
df['duration_interval'] = pd.cut(df['duration_min'], bins=bin_edges)

# Create a histogram dataframe
histogram_df = df['duration_interval'].value_counts().sort_index().reset_index()
histogram_df.columns = ['Duration Interval (min)', 'Frequency']

# Print the histogram dataframe
display(histogram_df)
# Out:
#   Duration Interval (min)  Frequency
# 0              (0.0, 5.0]       3132
# 1             (5.0, 10.0]        247

# %%
# Filter songs with duration over 10 minutes or below 1 minute
duration_outliers = df[(df['duration_min'] > 12) | (df['duration_min'] < 0.5)]

# Print the songs with duration over 10 minutes or below 1 minute
display(duration_outliers[['track_name', 'artists', 'album_name', 'track_genre', 'duration_min']])
# Out:
# Empty DataFrame
# Columns: [track_name, artists, album_name, track_genre, duration_min]
# Index: []

# %%
import matplotlib.pyplot as plt

# Get the top 10 genres by frequency
top_genres = df['track_genre'].value_counts().head(10)

# Plot a bar chart
plt.figure(figsize=(16, 8))
top_genres.plot(kind='bar', color='skyblue')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Top 10 Genres by Frequency')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3379 entries, 0 to 3378
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           3379 non-null   object
#  1   artists            3379 non-null   object
#  2   album_name         3379 non-null   object
#  3   track_name         3379 non-null   object
#  4   popularity         3379 non-null   int64
#  5   duration_ms        3379 non-null   int64
#  6   explicit           3379 non-null   bool
#  7   danceability       3379 non-null   float64
#  8   energy             3379 non-null   float64
#  9   key                3379 non-null   int64
#  10  loudness           3379 non-null   float64
#  11  mode               3379 non-null   int64
#  12  speechiness        3379 non-null   float64
#  13  acousticness       3379 non-null   float64
#  14  instrumentalness   3379 non-null   float64
#  15  liveness           3379 non-null   float64
#  16  valence            3379 non-null   float64
#  17  tempo              3379 non-null   float64
#  18  time_signature     3379 non-null   int64
#  19  track_genre        3379 non-null   object
#  20  YouTube URL        3379 non-null   object
#  21  duration_min       3379 non-null   float64
#  22  duration_interval  3379 non-null   category
# dtypes: bool(1), category(1), float64(10), int64(5), object(6)
# memory usage: 587.5+ KB

# %% [markdown]
# ### Features Engineering

# %%
# !pip install fasttext

# %%
import fasttext

# Combine the text columns into a single string for each row and save to a text file
text_data = df['artists'] + ' ' + df['track_name'] + ' ' + df['album_name'] + ' ' + df['track_genre']
text_data.to_csv('text_data.txt', index=False, header=False)

# Train the fastText model on the text data
model = fasttext.train_unsupervised('text_data.txt', model='skipgram')

# %%
def get_mean_embedding(words_list, model):
    embeddings = [model.get_word_vector(word) for word in words_list]
    mean_embedding = np.mean(embeddings, axis=0)
    return mean_embedding

# Function to handle multiple artists and get their mean embedding
def get_artists_embedding(artists, model):
    # Split the artists string into individual artists
    artists_list = artists.split(';')
    # Get the mean embedding for the list of artists
    return get_mean_embedding(artists_list, model)

# %%
from sklearn.preprocessing import StandardScaler

def get_track_embedding(track, model):
    # Get the embeddings as before
    artists_embedding = get_artists_embedding(track['artists'], model)
    track_name_embedding = get_mean_embedding(track['track_name'].split(), model)
    album_name_embedding = get_mean_embedding(track['album_name'].split(), model)
    track_genre_embedding = get_mean_embedding(track['track_genre'].split(), model)

    # Get the numerical features
    numerical_features = np.array([track['popularity'], track['duration_ms'], track['danceability'], track['loudness'], track['energy'], track['speechiness'], track['instrumentalness'], track['liveness'], track['valence'], track['tempo']])
    

    # Normalize the numerical features to have the same scale as the embeddings
    # This step is important to ensure that the numerical features do not dominate the embeddings
    scaler = StandardScaler()
    normalized_numerical_features = scaler.fit_transform(numerical_features.reshape(-1, 1))

    # Flatten the normalized numerical features to 1D
    normalized_numerical_features = normalized_numerical_features.flatten()

    # Concatenate the embeddings and the numerical features
    final_embedding = artists_embedding + track_name_embedding + album_name_embedding + track_genre_embedding
    final_embedding = np.concatenate([final_embedding, normalized_numerical_features])

    return final_embedding

# %%
# Calculate embeddings for all tracks
df['embedding'] = df.apply(lambda x: get_track_embedding(x, model), axis=1)

# %%
len(df['embedding'][0])
# Out:
# 110

# %%
from annoy import AnnoyIndex

# Assuming the dimension of your embeddings is 128
t = AnnoyIndex(len(df['embedding'][0]), 'angular')  

# Build the Annoy index
for i, row in df.iterrows():
    t.add_item(i, row['embedding'])

# Build the index, 10 trees are being used in this example
t.build(10)
# Out:
# True

# %%
df[df['artists'].str.contains('BLACK')]
# Out:
#                      track_id                 artists  \
# 20462  13hvHEstJ4sNbzdroPrPI3      Dua Lipa;BLACKPINK
# 21372  0Xoj0t3aqkviPAomSMjrXs  Myssa More;BLACKGRAPES
# 65013  7EyhPjrJzjx0fk2i7vUJCS               BLACKPINK
# 65015  3BHR1mJOqn2UZyq98YKPgd               BLACKPINK
# 65016  1I2MEjnS9c4OPMnKWbIuYs               BLACKPINK
# 65017  6bvZRLLkBKkmgpBJTTj3QK               BLACKPINK
# 65019  6tCd8bPvYnceDG7W9M1RMk               BLACKPINK
# 65028  69BIczdH6QMnFx7dsSssN8               BLACKPINK
# 65033  5P3o95Jf0YBQRQ4j2XPpfC               BLACKPINK
# 65059  6Ho58vQUjGnBU9m8Z6uNcv               BLACKPINK
# 65062  28tufPkTcXmdNqTvi9hsoG               BLACKPINK
# 65063  1cdbkpZ3q1KYZDNSrOpdkb  BLACKPINK;Selena Gomez
# 65064  34TQk2yqzMX6X3AAAOeUvT               BLACKPINK
# 65067  1GMufNnkKAnPLnqKJ5HHxW               BLACKPINK
# 65074  5GK7eDDTVz7CTge1wJrDQW               BLACKPINK
# 65082  13MF2TYuyfITClL1R2ei6e               BLACKPINK
# 65084  4ZxOuNHhpyOj4gv52MtQpT               BLACKPINK
# 65086  3ABi5sVjvEp08IQEKh8BmG               BLACKPINK
# 65088  21hB8x6QTEsTfIDENPcyXm               BLACKPINK
# 65094  61tqrU7wp1EnoJ5ajtYXMl               BLACKPINK
# 65122  7qmvLmX9tyaTiBAVNI6YEn               BLACKPINK
# 65123  6NEoeBLQbOMw92qMeLfI40               BLACKPINK
# 65183  3Gk1LfB771PIEGgsEa7gcV               BLACKPINK
# 65219  2Pp9osgyIcw6o1avfDDDhH               BLACKPINK
# 65270  7bi5vk9KoY6Flkat31ViYD               BLACKPINK
# 65281  00J8yszzb5PR6ZIvSBtg0Y               BLACKPINK
# 65320  1dMN2vSRoKEGnIjDOmzmrz               BLACKPINK
# 65322  4ghGrdxwqLA6ZoCiu0u4IR               BLACKPINK
# 65337  3tP6QKbXvtrxiDI7QwKyUf               BLACKPINK
# 65381  0NFjUVEW0ndIiodGuMhHQU               BLACKPINK
# 65425  3AgMOlgdrG9RJXDWifcjVd       BLACKPINK;Cardi B
# 65499  6X9DNG2WR3IclfneGurU0T               BLACKPINK
# 65519  4HxVweMysEnuYxy3gkFtKk               BLACKPINK
# 65526  0Rl04KI0zAZAbS9WbUKj1F               BLACKPINK
# 65532  3VN74YiIjtY5ouKahBjmRX               BLACKPINK
# 65559  5RBH8ypFAj5HTZTPRpI1XL               BLACKPINK
# 65639  1fMXWEkJpIH483OrKn1zFV               BLACKPINK
# 65666  2hPJcTRIOEqCWTMpYQZNnr               BLACKPINK
# 65678  29fsVDL9T36N0tyD7ByLdI               BLACKPINK
# 65713  3pkIaou3w14ytyKYZbg0hc               BLACKPINK
# 65846  5nIjOnMbC0QDMrYFLGx0yV               BLACKPINK
# 65874  20MOKIGONywL5xIoB7RRAR               BLACKPINK
# 65989  4k2iYdpCZYH3eQX2bVKOku               BLACKPINK
# 65997  4jUEHIrc443f743JbyLN0y               BLACKPINK
#
#                                               album_name  \
# 20462                        Dua Lipa (Complete Edition)
# 21372                                       Tick an Tock
# 65013                                         Pink Venom
# 65015                                          BORN PINK
# 65016                                          BORN PINK
# 65017                                          THE ALBUM
# 65019                                          BORN PINK
# 65028                                          SQUARE UP
# 65033                                          BORN PINK
# 65059                                          BORN PINK
# 65062                                          THE ALBUM
# 65063                                          THE ALBUM
# 65064                                          BORN PINK
# 65067                                          THE ALBUM
# 65074                                     Kill This Love
# 65082                                         SQUARE ONE
# 65084                               As If It's Your Last
# 65086                                          BORN PINK
# 65088                                          BORN PINK
# 65094                                          BORN PINK
# 65122                                         SQUARE TWO
# 65123                                         SQUARE ONE
# 65183                                          THE ALBUM
# 65219                                          SQUARE UP
# 65270                                          THE ALBUM
# 65281                                          THE ALBUM
# 65320                                          BORN PINK
# 65322                                     Kill This Love
# 65337                                         SQUARE TWO
# 65381                                          BORN PINK
# 65425                                          THE ALBUM
# 65499  BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KY...
# 65519                                          SQUARE UP
# 65526                                          BORN PINK
# 65532                                     Kill This Love
# 65559                                          SQUARE UP
# 65639  BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KY...
# 65666                                          BORN PINK
# 65678                                     Kill This Love
# 65713                                     Kill This Love
# 65846          BLACKPINK IN YOUR AREA (Japanese Version)
# 65874                                         SQUARE TWO
# 65989   'BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live
# 65997          BLACKPINK IN YOUR AREA (Japanese Version)
#
#                                               track_name  popularity  \
# 20462                                   Kiss and Make Up          59
# 21372                                       Tick an Tock          33
# 65013                                         Pink Venom          85
# 65015                                          Typa Girl          82
# 65016                                       Hard to Love          80
# 65017                                  How You Like That          75
# 65019                                          Shut Down          87
# 65028                                      DDU-DU DDU-DU          71
# 65033                                         Pink Venom          83
# 65059                                              Tally          78
# 65062                                      Pretty Savage          71
# 65063                      Ice Cream (with Selena Gomez)          70
# 65064                                          Shut Down          73
# 65067                                     Lovesick Girls          73
# 65074                                     Kill This Love          71
# 65082                                          BOOMBAYAH          77
# 65084                               As If It's Your Last          77
# 65086                                     Yeah Yeah Yeah          77
# 65088                                  The Happiest Girl          78
# 65094                                     Ready For Love          76
# 65122                                  PLAYING WITH FIRE          75
# 65123                                            WHISTLE          74
# 65183                                    Love To Hate Me          67
# 65219                                      Forever Young          67
# 65270                                     Crazy Over You          66
# 65281                                     You Never Know          66
# 65320                                  The Happiest Girl          67
# 65322                              Don't Know What To Do          66
# 65337                                               STAY          71
# 65381                                     Ready For Love          64
# 65425                      Bet You Wanna (Feat. Cardi B)          64
# 65499  Kiss and Make Up - BLACKPINK ARENA TOUR 2018 "...          59
# 65519                                             Really          63
# 65526                                     Yeah Yeah Yeah          63
# 65532                                            Kick It          63
# 65559                                        See U Later          62
# 65639  SO HOT - THEBLACKLABEL REMIX BLACKPINK ARENA T...          64
# 65666                                          Typa Girl          61
# 65678                                           Hope Not          63
# 65713                              DDU-DU DDU-DU (Remix)          58
# 65846                       BOOMBAYAH - Japanese Version          62
# 65874                            WHISTLE - Acoustic Ver.          62
# 65989                               DDU-DU DDU-DU (Live)          55
# 65997                   DDU-DU DDU-DU - Japanese Version          61
#
#        duration_ms  explicit  danceability  energy  key  ...  acousticness  \
# 20462       190560     False         0.675   0.729    8  ...       0.05570
# 21372       185260     False         0.835   0.400    8  ...       0.09380
# 65013       186964     False         0.794   0.719    0  ...       0.01190
# 65015       179172      True         0.918   0.585    7  ...       0.06270
# 65016       162569      True         0.647   0.723    5  ...       0.00503
# 65017       180956     False         0.813   0.787   11  ...       0.04520
# 65019       175889     False         0.813   0.657    0  ...       0.00269
# 65028       209355     False         0.671   0.859    4  ...       0.03130
# 65033       186964     False         0.794   0.719    0  ...       0.01190
# 65059       184248      True         0.693   0.606    7  ...       0.00817
# 65062       199122     False         0.699   0.588    9  ...       0.00807
# 65063       175813     False         0.791   0.733    9  ...       0.03050
# 65064       175889     False         0.813   0.657    0  ...       0.00269
# 65067       192765     False         0.658   0.732    6  ...       0.00513
# 65074       189052     False         0.738   0.861    2  ...       0.31800
# 65082       240793     False         0.661   0.836    5  ...       0.00268
# 65084       213264     False         0.786   0.852    8  ...       0.06870
# 65086       178923     False         0.732   0.555    1  ...       0.00522
# 65088       222025     False         0.439   0.352    0  ...       0.58700
# 65094       184677     False         0.564   0.682    6  ...       0.01460
# 65122       197288     False         0.706   0.756    4  ...       0.03920
# 65123       211631     False         0.818   0.723   11  ...       0.00561
# 65183       169797     False         0.689   0.656    8  ...       0.03650
# 65219       237076     False         0.592   0.961    4  ...       0.04230
# 65270       161945     False         0.805   0.660    4  ...       0.03670
# 65281       229201     False         0.527   0.462    5  ...       0.22700
# 65320       222025     False         0.439   0.352    0  ...       0.58700
# 65322       201081     False         0.628   0.640    6  ...       0.09920
# 65337       230322     False         0.630   0.432    1  ...       0.55100
# 65381       184677     False         0.564   0.682    6  ...       0.01460
# 65425       159168     False         0.541   0.688    7  ...       0.00479
# 65499       190500     False         0.650   0.697    0  ...       0.13000
# 65519       197789     False         0.696   0.881    1  ...       0.02350
# 65526       178923     False         0.732   0.555    1  ...       0.00522
# 65532       191225     False         0.765   0.787    1  ...       0.01560
# 65559       198866     False         0.740   0.926    9  ...       0.03760
# 65639       144166     False         0.783   0.809    1  ...       0.05880
# 65666       179172     False         0.917   0.596    7  ...       0.05550
# 65678       191030     False         0.556   0.423    4  ...       0.44100
# 65713       201225     False         0.680   0.906   11  ...       0.03410
# 65846       240613     False         0.748   0.868    5  ...       0.02250
# 65874       212419     False         0.844   0.462    1  ...       0.80400
# 65989       210268     False         0.563   0.902   11  ...       0.01840
# 65997       209493     False         0.703   0.845   11  ...       0.02960
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 20462          0.000000    0.1890    0.630   99.986               4
# 21372          0.067900    0.1030    0.523  103.657               4
# 65013          0.000000    0.2760    0.690   90.016               4
# 65015          0.000000    0.6240    0.519  131.966               4
# 65016          0.000000    0.1760    0.443  105.001               4
# 65017          0.000107    0.0506    0.326  130.018               4
# 65019          0.000000    0.1830    0.651  110.053               3
# 65028          0.000000    0.2670    0.390  139.931               4
# 65033          0.000000    0.2760    0.690   90.016               4
# 65059          0.000000    0.0942    0.447  129.942               4
# 65062          0.000131    0.1070    0.350  151.971               4
# 65063          0.000169    0.0423    0.913  159.974               4
# 65064          0.000000    0.1830    0.651  110.053               3
# 65067          0.000000    0.1300    0.409  127.995               4
# 65074          0.001820    0.3250    0.580  131.980               4
# 65082          0.000000    0.4970    0.396  124.952               4
# 65084          0.000000    0.0759    0.455  125.036               4
# 65086          0.000005    0.0586    0.650  124.011               4
# 65088          0.000000    0.1400    0.548  181.517               3
# 65094          0.000000    0.1230    0.551  107.597               4
# 65122          0.000000    0.1800    0.676   97.098               4
# 65123          0.000000    0.0866    0.607  102.945               4
# 65183          0.000000    0.1360    0.623  162.269               4
# 65219          0.000000    0.0882    0.508  109.826               4
# 65270          0.000064    0.2150    0.617  114.954               4
# 65281          0.000000    0.1640    0.334  144.573               4
# 65320          0.000000    0.1400    0.548  181.517               3
# 65322          0.000000    0.1380    0.409  129.815               4
# 65337          0.000006    0.0962    0.343   87.959               4
# 65381          0.000000    0.1230    0.551  107.597               4
# 65425          0.000000    0.0733    0.649  109.843               4
# 65499          0.000000    0.8620    0.551   99.771               4
# 65519          0.000000    0.2770    0.947  142.019               4
# 65526          0.000005    0.0586    0.650  124.011               4
# 65532          0.000000    0.0736    0.381  124.949               4
# 65559          0.000000    0.5820    0.571  106.987               4
# 65639          0.000010    0.5150    0.814  140.025               4
# 65666          0.000000    0.6670    0.511  131.960               4
# 65678          0.000000    0.0867    0.179  110.086               4
# 65713          0.000078    0.0770    0.680  145.050               4
# 65846          0.000005    0.3670    0.513  124.952               4
# 65874          0.000000    0.0923    0.636  102.940               4
# 65989          0.000005    0.3680    0.364  139.939               4
# 65997          0.000000    0.2130    0.428  139.936               4
#
#        track_genre  duration_min  duration_interval  \
# 20462        dance      3.176000         (0.0, 5.0]
# 21372    dancehall      3.087667         (0.0, 5.0]
# 65013        k-pop      3.116067         (0.0, 5.0]
# 65015        k-pop      2.986200         (0.0, 5.0]
# 65016        k-pop      2.709483         (0.0, 5.0]
# 65017        k-pop      3.015933         (0.0, 5.0]
# 65019        k-pop      2.931483         (0.0, 5.0]
# 65028        k-pop      3.489250         (0.0, 5.0]
# 65033        k-pop      3.116067         (0.0, 5.0]
# 65059        k-pop      3.070800         (0.0, 5.0]
# 65062        k-pop      3.318700         (0.0, 5.0]
# 65063        k-pop      2.930217         (0.0, 5.0]
# 65064        k-pop      2.931483         (0.0, 5.0]
# 65067        k-pop      3.212750         (0.0, 5.0]
# 65074        k-pop      3.150867         (0.0, 5.0]
# 65082        k-pop      4.013217         (0.0, 5.0]
# 65084        k-pop      3.554400         (0.0, 5.0]
# 65086        k-pop      2.982050         (0.0, 5.0]
# 65088        k-pop      3.700417         (0.0, 5.0]
# 65094        k-pop      3.077950         (0.0, 5.0]
# 65122        k-pop      3.288133         (0.0, 5.0]
# 65123        k-pop      3.527183         (0.0, 5.0]
# 65183        k-pop      2.829950         (0.0, 5.0]
# 65219        k-pop      3.951267         (0.0, 5.0]
# 65270        k-pop      2.699083         (0.0, 5.0]
# 65281        k-pop      3.820017         (0.0, 5.0]
# 65320        k-pop      3.700417         (0.0, 5.0]
# 65322        k-pop      3.351350         (0.0, 5.0]
# 65337        k-pop      3.838700         (0.0, 5.0]
# 65381        k-pop      3.077950         (0.0, 5.0]
# 65425        k-pop      2.652800         (0.0, 5.0]
# 65499        k-pop      3.175000         (0.0, 5.0]
# 65519        k-pop      3.296483         (0.0, 5.0]
# 65526        k-pop      2.982050         (0.0, 5.0]
# 65532        k-pop      3.187083         (0.0, 5.0]
# 65559        k-pop      3.314433         (0.0, 5.0]
# 65639        k-pop      2.402767         (0.0, 5.0]
# 65666        k-pop      2.986200         (0.0, 5.0]
# 65678        k-pop      3.183833         (0.0, 5.0]
# 65713        k-pop      3.353750         (0.0, 5.0]
# 65846        k-pop      4.010217         (0.0, 5.0]
# 65874        k-pop      3.540317         (0.0, 5.0]
# 65989        k-pop      3.504467         (0.0, 5.0]
# 65997        k-pop      3.491550         (0.0, 5.0]
#
#                                                embedding
# 20462  [-0.7399092316627502, 0.4943411350250244, 0.56...
# 21372  [-0.390157550573349, 1.4122482538223267, 0.096...
# 65013  [0.6428433656692505, -1.3818964958190918, 0.53...
# 65015  [0.4201085567474365, -1.1071395874023438, 0.89...
# 65016  [0.1990181803703308, -0.777794599533081, 1.159...
# 65017  [0.19331488013267517, -0.34126967191696167, 1....
# 65019  [0.2627940773963928, -0.9457228183746338, 0.73...
# 65028  [0.26694440841674805, -0.5964429378509521, 0.9...
# 65033  [0.45537465810775757, -1.2047795057296753, 0.8...
# 65059  [-0.1651480793952942, -0.51210618019104, 1.104...
# 65062  [-0.004475593566894531, -0.47613072395324707, ...
# 65063  [0.18082156777381897, 0.08237278461456299, 0.7...
# 65064  [0.2627940773963928, -0.9457228183746338, 0.73...
# 65067  [0.1477833390235901, -0.6998544335365295, 1.19...
# 65074  [0.39336878061294556, -0.9710614681243896, 1.5...
# 65082  [0.38665640354156494, -0.5851585865020752, 0.9...
# 65084  [-0.6169316172599792, -0.6837896108627319, 0.5...
# 65086  [-0.10203319787979126, -0.9411147236824036, 0....
# 65088  [0.25499227643013, -0.9265667796134949, 0.9360...
# 65094  [-0.038786113262176514, -1.1890583038330078, 1...
# 65122  [0.3789909780025482, -0.5432275533676147, 1.00...
# 65123  [0.18990471959114075, -0.5961248874664307, 1.0...
# 65183  [0.13457626104354858, -0.5204856395721436, 1.2...
# 65219  [-0.2022080421447754, -1.0672143697738647, 0.9...
# 65270  [-0.17475897073745728, -0.6605855226516724, 1....
# 65281  [-0.05935853719711304, -0.5435598492622375, 1....
# 65320  [0.25499227643013, -0.9265667796134949, 0.9360...
# 65322  [0.1813460886478424, -0.8337486386299133, 0.90...
# 65337  [0.15555429458618164, -0.36869263648986816, 0....
# 65381  [-0.038786113262176514, -1.1890583038330078, 1...
# 65425  [-0.0468255877494812, 0.240592360496521, 0.910...
# 65499  [0.05292269587516785, -0.685580849647522, 1.04...
# 65519  [-0.4046132564544678, -0.411487340927124, 0.93...
# 65526  [-0.10203319787979126, -0.9411147236824036, 0....
# 65532  [-0.09387737512588501, -0.502342700958252, 0.8...
# 65559  [-0.024342775344848633, -0.4967164993286133, 0...
# 65639  [0.14443045854568481, -0.8214860558509827, 1.0...
# 65666  [0.4201085567474365, -1.1071395874023438, 0.89...
# 65678  [0.6137727499008179, -1.085993766784668, 1.462...
# 65713  [0.42184382677078247, -0.8470456600189209, 0.9...
# 65846  [0.1702972948551178, -1.1275534629821777, 0.98...
# 65874  [0.1543826162815094, -0.9376869797706604, 1.11...
# 65989  [-0.1243467926979065, -1.1590445041656494, 1.1...
# 65997  [0.13994231820106506, -1.0723519325256348, 1.0...
#
# [44 rows x 23 columns]

# %%
df.sample(5)
# Out:
#                      track_id                    artists  \
# 14132  68XmRvKqdw5tPW98yK5alK             Rolf Zuckowski
# 48081  5fr4xVMb7UsHsMOUXvLr2I          Das EFX;Pete Rock
# 2880   36DsPKPZurixiFVcZ4XONb                       Cuca
# 33002  7AQim7LbvFVZJE3O8TYgf2  XXXTENTACION;Trippie Redd
# 21397  0NcWI0my7uo4OCbqubBp1L                 Lutan Fyah
#
#                                               album_name  \
# 14132  Bei uns in der Kita - 22 Lieder im Frühling + ...
# 48081                                       Rap Classics
# 2880                                            La Racha
# 33002                                                 17
# 21397                                      Solace Riddim
#
#                            track_name  popularity  duration_ms  explicit  \
# 14132            Als ich ein Baby war          41       248706     False
# 48081  Real Hip-Hop - Pete Rock Remix           0       260933     False
# 2880                        La Balada          45       290666     False
# 33002  Fuck Love (feat. Trippie Redd)          83       146520      True
# 21397                     Think Twice           0       191466     False
#
#        danceability  energy  key  ...  acousticness  instrumentalness  \
# 14132         0.809   0.734   10  ...        0.2730          0.000000
# 48081         0.727   0.869   10  ...        0.1210          0.000000
# 2880          0.671   0.512    8  ...        0.2720          0.000000
# 33002         0.797   0.533    0  ...        0.0172          0.000152
# 21397         0.670   0.665    0  ...        0.1010          0.000000
#
#        liveness  valence    tempo  time_signature  track_genre  duration_min  \
# 14132     0.140    0.897  120.610               4     children      4.145100
# 48081     0.104    0.837   93.080               4     hardcore      4.348883
# 2880      0.102    0.187   95.782               4     alt-rock      4.844433
# 33002     0.103    0.329  131.036               4          emo      2.442000
# 21397     0.106    0.537   84.976               4    dancehall      3.191100
#
#        duration_interval                                          embedding
# 14132         (0.0, 5.0]  [-0.11337955296039581, 0.7158562541007996, -0....
# 48081         (0.0, 5.0]  [-0.29434096813201904, 0.12654781341552734, 0....
# 2880          (0.0, 5.0]  [-0.2594074010848999, 0.9017314314842224, -0.6...
# 33002         (0.0, 5.0]  [-0.5992158651351929, -0.12206357717514038, 0....
# 21397         (0.0, 5.0]  [0.27656203508377075, 0.4253951907157898, -0.0...
#
# [5 rows x 23 columns]

# %%
import random

# Select a random track from the dataframe
index = 65678

# Get the embedding of the random track
random_track_embedding = df.loc[index, 'embedding']

# Find the 10 nearest neighbors to the random track
nearest_neighbors_indices = t.get_nns_by_vector(random_track_embedding, 10)

# Get the details of the recommended tracks
recommended_tracks = df.loc[nearest_neighbors_indices]

recommended_tracks[['artists', 'track_name', 'album_name', 'track_genre', 'popularity', 'duration_min', 'danceability']]
# Out:
#          artists             track_name  \
# 65678  BLACKPINK               Hope Not
# 65074  BLACKPINK         Kill This Love
# 65322  BLACKPINK  Don't Know What To Do
# 65713  BLACKPINK  DDU-DU DDU-DU (Remix)
# 65532  BLACKPINK                Kick It
# 65231        BTS              Not Today
# 65488        BTS                   Dope
# 65395        BTS                   Dope
# 65185        BTS               I Need U
# 65621        BTS              Look Here
#
#                                              album_name track_genre  \
# 65678                                    Kill This Love       k-pop
# 65074                                    Kill This Love       k-pop
# 65322                                    Kill This Love       k-pop
# 65713                                    Kill This Love       k-pop
# 65532                                    Kill This Love       k-pop
# 65231                              You Never Walk Alone       k-pop
# 65488  The Most Beautiful Moment in Life: Young Forever       k-pop
# 65395            The Most Beautiful Moment in Life Pt.1       k-pop
# 65185            The Most Beautiful Moment in Life Pt.1       k-pop
# 65621                                       Dark & Wild       k-pop
#
#        popularity  duration_min  danceability
# 65678          63      3.183833         0.556
# 65074          71      3.150867         0.738
# 65322          66      3.351350         0.628
# 65713          58      3.353750         0.680
# 65532          63      3.187083         0.765
# 65231          71      3.864317         0.593
# 65488          64      4.000333         0.579
# 65395          68      4.000333         0.595
# 65185          71      3.516433         0.478
# 65621          63      3.648117         0.863
